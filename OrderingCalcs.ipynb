# %%
import json
from datetime import datetime
import numpy

with open('kegs.json') as data_file:
    dict = json.load(data_file)

stats = {}

#Drive through list collecting stats
for keg in dict['objects']:

    name = "%s %s" % (keg['beverage']['producer']['name'], keg['beverage']['name'])
  
    volume = keg['full_volume_ml']
    date_format = '%Y-%m-%dT%H:%M:%S+00:00'
    start_time = datetime.strptime(keg['start_time'],date_format)
    end_time = datetime.strptime(keg['end_time'],date_format)
    delta = end_time - start_time
    seconds = delta.total_seconds()
 
    if seconds > 0: #sainity check
        rate_ml_s = int(volume) / seconds
        rate_l_day = rate_ml_s * 86.4
        rate_l_week = rate_l_day * 7
 
        if 1 < rate_l_week < 1000: #sanity check
            
            if name not in stats:
                stats[name] = {}
                stats[name]['rate'] = []
                stats[name]['date'] = start_time

            stats[name]['rate'].append(rate_l_week)
            if stats[name]['date'] < start_time:
                stats[name]['date'] = start_time

#Average the rates
for name, stat in stats.iteritems():
    stat['rate'] = numpy.mean(stat['rate'])
    #print name, numpy.mean(stat['rate'])

#Display in order
for w in sorted(stats, key=lambda rate:stats[rate]['rate'], reverse=True):
    print "{:3.0f} liters/wk {:3d} days ago, {}".format(
        stats[w]['rate'], (datetime.today() -stats[w]['date']).days, w)
# Out:
# 324 liters/wk 370 days ago, North Country Hard Cider Company Original Press
# 322 liters/wk 489 days ago, Throwback Brewery Hog Happy Hefeweizen
# 313 liters/wk 362 days ago, Negra Modelo Negra Modelo
# 242 liters/wk 433 days ago, Able Ebenezer Auburn Ale
# 241 liters/wk 490 days ago, Throwback Brewery White Heron Chai Porter
# 208 liters/wk 356 days ago, Dogfish Head 60min IPA
# 203 liters/wk 414 days ago, Throwback Brewery Oma's Tribute
# 202 liters/wk  33 days ago, Dogfish Head Burton Baton
# 164 liters/wk 190 days ago, Samuel Adams Summer Ale
# 137 liters/wk 217 days ago, Sam Adams Boston Lager
# 129 liters/wk  13 days ago, Shipyard Monkey Fist IPA
# 109 liters/wk  77 days ago, Henniker Brewing Working Man's Porter
# 107 liters/wk 334 days ago, Brooklyn Brewery Brooklyn Lager
#  97 liters/wk 119 days ago, Long Trail Long Trail Ale
#  88 liters/wk  67 days ago, Switchback Switchback Ale
#  83 liters/wk 432 days ago, Guinness Guinness Draught
#  71 liters/wk  53 days ago, Dogfish Head 90min IPA
#  60 liters/wk 319 days ago, Moat Mountain Brewery Hell Yes!
#  59 liters/wk 312 days ago, Lagunitas Pils
